# %% [markdown]
# # Final Project

# %% [markdown]
# ### Handle dataset

# %%
# Read in data.
import numpy as np
import pandas as pd
data_original = pd.read_csv("data/final_data.csv")

# %%
data_original.head(5)
# Out:
#   State                     Districtname  \
# 0    AR     BENTON COUNTY SCHOOL OF ARTS
# 1    AR             LISA ACADEMY CHARTER
# 2    AR         ARKANSAS VIRTUAL ACADEMY
# 3    AR  JACKSONVILLE LIGHTHOUSE CHARTER
# 4    AR  LITTLE ROCK PREPARATORY ACADEMY
#
#                                        Schoolname  Student Number  \
# 0  ARKANSAS ARTS ACADEMY ELEMENTARY/MIDDLE SCHOOL             532
# 1                                    LISA ACADEMY             484
# 2                     ARKANSAS VIRTUAL ACADEMY JR             630
# 3              JACKSONVILLE LIGHTHOUSE ELEMENTARY             389
# 4                        LITTLE ROCK PREP ACADEMY             118
#
#    Teacher Ratio  Child Poverty Ratio  Poverty_Ratio  Poverty School  \
# 0      12.953494            39.285714          10.20        0.128263
# 1      15.567707            40.082645          13.53        0.244510
# 2      65.082645            29.047619          13.53        0.244510
# ...

# %%
data_handled_1 = data_original.drop(['State', 'Districtname', 'Schoolname', 'Student Number',
                                            'Teacher Ratio', 'Poverty School', 'Child Poverty Ratio',
                                            'Go-to College Ratio', 'Unemployment', 'Poverty_Ratio'], axis=1)
data_handled_1.head(5)
# Out:
#    Population_Density  Student_Number  Teacher_Ratio  Child_Poverty_Ratio  \
# 0            385.2326             532      12.953494            39.285714
# 1           1840.0550             484      15.567707            40.082645
# 2           1840.0550             630      65.082645            29.047619
# 3            231.8521             389      21.587125            68.894602
# 4           1840.0550             118      10.260870           100.000000
#
#    Attend_College_Ratio  Unemployment_Ratio  Poverty_School
# 0                 26.42                3.69       12.826346
# 1                 36.70                6.79       24.451019
# 2                 36.70                6.79       24.451019
# 3                 30.68                5.36       17.831723
# 4                 36.70                6.79       24.451019

# %%
data_handled_2 = data_handled_1.dropna()
data_handled_2.reset_index(drop=True, inplace=True)
data_handled_2
# Out:
#      Population_Density  Student_Number  Teacher_Ratio  Child_Poverty_Ratio  \
# 0            385.232600             532      12.953494            39.285714
# 1           1840.055000             484      15.567707            40.082645
# 2           1840.055000             630      65.082645            29.047619
# 3            231.852100             389      21.587125            68.894602
# 4           1840.055000             118      10.260870           100.000000
# ..                  ...             ...            ...                  ...
# 459         4782.319000             505      20.362903            74.455446
# 460         4313.245000             542      16.183936            61.808118
# 461         4513.286000             381      15.393939            28.871391
# 462         4447.760000             109       9.372313            21.100917
# 463            8.852928             187      10.564972            17.112299
#
# ...

# %%
data_handled_3 = data_handled_2[(data_handled_2['Teacher_Ratio'] >= 0) & (data_handled_2['Teacher_Ratio'] <= 100) &
                                (data_handled_2['Poverty_School'] >= 0) & (data_handled_2['Poverty_School'] <= 100)&
                                (data_handled_2['Attend_College_Ratio'] >= 0) & (data_handled_2['Attend_College_Ratio'] <= 100)&
                                (data_handled_2['Unemployment_Ratio'] >= 0) & (data_handled_2['Unemployment_Ratio'] <= 100)&
                                (data_handled_2['Child_Poverty_Ratio'] >= 0) & (data_handled_2['Child_Poverty_Ratio'] <= 100)]
data_handled_3.reset_index(drop=True, inplace=True)
data_handled_3
# Out:
#      Population_Density  Student_Number  Teacher_Ratio  Child_Poverty_Ratio  \
# 0            385.232600             532      12.953494            39.285714
# 1           1840.055000             484      15.567707            40.082645
# 2           1840.055000             630      65.082645            29.047619
# 3            231.852100             389      21.587125            68.894602
# 4           1840.055000             118      10.260870           100.000000
# ..                  ...             ...            ...                  ...
# 455         4782.319000             505      20.362903            74.455446
# 456         4313.245000             542      16.183936            61.808118
# 457         4513.286000             381      15.393939            28.871391
# 458         4447.760000             109       9.372313            21.100917
# 459            8.852928             187      10.564972            17.112299
#
# ...

# %% [markdown]
# Finally, there are 491 rows of data we can use.

# %% [markdown]
# ### Plot data

# %%
import matplotlib
import matplotlib.pyplot as plt

Population_Density = data_handled_3.Population_Density
Student_Number = data_handled_3.Student_Number
Teacher_Ratio = data_handled_3.Teacher_Ratio
Poverty_School = data_handled_3.Poverty_School
Attend_College_Ratio = data_handled_3.Attend_College_Ratio
Child_Poverty_Ratio = data_handled_3.Child_Poverty_Ratio
Unemployment_Ratio = data_handled_3.Unemployment_Ratio

# %%
# Firstly, just try simply plot

plt.plot(Poverty_School)
plt.plot(Teacher_Ratio)
plt.plot(Attend_College_Ratio)
plt.plot(Unemployment_Ratio)

plt.title('Education in US, Poverty_School/Teacher/Attend_College/Unemployment Ratio')
plt.ylabel('Poverty/Teacher/Attend_College/Unemployment Ratio')
plt.xlabel('Count')
plt.grid(True)

# %% [markdown]
# That's a mess, let's try other plots!

# %% [markdown]
# ### Now try seaborn

# %%
import seaborn as sns

# Scatter plot showing the relationship between Population_Density and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Population_Density, Unemployment_Ratio, scatter=True, fit_reg=True)
plt.grid(True)

# %% [markdown]
# There is an increasing relationship between Population_Density and Unemployment_Ratio!

# %%
# Scatter plot showing the relationship between Student_Number and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Student_Number, Unemployment_Ratio, scatter=True, fit_reg=True)
plt.grid(True)

# %% [markdown]
# Seems no relationship between Student_Number and Unemployment_Ratio.

# %%
# Scatter plot showing the relationship between Teacher_Ratio and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Teacher_Ratio, Unemployment_Ratio, scatter=True, fit_reg=True)
plt.grid(True)

# %% [markdown]
# There is an increasing relationship between Teacher_Ratio and Unemployment_Ratio?? But all data point just stay gathering, maybe it's not liner relationship.

# %%
# Scatter plot showing the relationship between Poverty_School and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Poverty_School, Unemployment_Ratio, scatter=True, fit_reg=True)
#sns.regplot(Poverty_School, Unemployment_Ratio, ci=68, truncate=False)
plt.grid(True)

# %% [markdown]
# There is an increasing relationship between Poverty_School and Unemployment_Ratio!

# %%
# Scatter plot showing the relationship between Attend_College_Ratio and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Attend_College_Ratio, Unemployment_Ratio, scatter=True, fit_reg=True)
plt.grid(True)

# %% [markdown]
# There is a decreasing relationship between Attend_College_Ratio and Unemployment_Ratio!

# %%
# Scatter plot showing the relationship between Child_Poverty_Ratio and Unemployment_Ratio
# %matplotlib inline
sns.regplot(Child_Poverty_Ratio, Unemployment_Ratio, scatter=True, fit_reg=True)
plt.grid(True)

# %% [markdown]
# There is an increasing relationship between Child_Poverty_Ratio and Unemployment_Ratio!

# %% [markdown]
# #### So, we guess all variables except Student_Number affect unemployment rate! But we still want to make our model with all of variables.

# %% [markdown]
# But firstly, save our dataset as a new .csv file

# %%
#data_handled_3.to_csv('data/data_handled.csv', index=False)

# %% [markdown]
# Now we can try some model!

# %% [markdown]
# ### Modeling

# %%
# Import all needed libraries
from sklearn.model_selection import train_test_split, LeaveOneOut, GridSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, scale, StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, Ridge, Lasso
from sklearn import preprocessing

# %%
data = data_handled_3

# %% [markdown]
# Split the data into test and train data sets

# %% [markdown]
# - X_train - all the predictors
# - Y_train - target variable (Unemployment_Ratio)
# - X_test - all the predictors
# - Y_test - target variable (Unemployment_Ratio)
#
# Let's define X and Y before splitting the data

# %%
X = data.drop('Unemployment_Ratio', axis=1)

# %%
X_train, X_test, Y_train, Y_test  = train_test_split(X, data.Unemployment_Ratio, test_size=0.2, random_state=10)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (322, 6)
# (138, 6)
# (322,)
# (138,)

# %% [markdown]
# ### Regression Analysis
#
# Let us perform Multiple Linear Regression to analyze the relationship between independent and target variables.
#
# **Multiple linear regression -** It is a predictive analysis tool which is used to explain the relationship between one continuous dependent variable and two or more continuous/ categorical independent variables.

# %%
# Create an object lm for the LinearRegression model
lm = LinearRegression()
# Fit the model on the training data
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.api as sm
X = data[['Population_Density', 'Student_Number',
          'Child_Poverty_Ratio', 'Teacher_Ratio', 'Attend_College_Ratio', 'Poverty_School']]
Y = data['Unemployment_Ratio']
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:     Unemployment_Ratio   R-squared (uncentered):                   0.896
# Model:                            OLS   Adj. R-squared (uncentered):              0.895
# Method:                 Least Squares   F-statistic:                              653.7
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                   8.89e-220
# Time:                        16:52:16   Log-Likelihood:                         -1168.1
# No. Observations:                 460   AIC:                                      2348.
# Df Residuals:                     454   BIC:                                      2373.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# Let us look at all the features and thier respective coefficients.

# %%
# Features and their respective coefficients
coeffs_df = pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['Features', 'Estimated_Coefficients'])
coeffs_df.sort_values(by='Estimated_Coefficients', ascending=False)
# Out:
#                Features  Estimated_Coefficients
# 5        Poverty_School                0.246993
# 2   Child_Poverty_Ratio                0.050564
# 1        Student_Number                0.000352
# 0    Population_Density               -0.000074
# 3         Teacher_Ratio               -0.004744
# 4  Attend_College_Ratio               -0.038966

# %% [markdown]
# - It seems Poverty_School affect Unemployment_Ratio most!
# - Student_Number and Population_Density	have little sffection on Unemployment_Ratio.
# - According to the analysis, Attend_College_Ratio and Teacher_Ratio have negative correlation with Unemployment_Ratio.

# %% [markdown]
# Let us draw a regression plot between the test target values and predicted test values to assess how the model is performing.

# %%
g = sns.regplot(x=lm.predict(X_test), y=Y_test, fit_reg=True)
g.set(xlabel='Predicted Unemployment', ylabel='Actual Unemployment', title='Model Predictions')
plt.title('Regression Plot for Actual vs Predicted Values')
# Out:
# Text(0.5, 1.0, 'Regression Plot for Actual vs Predicted Values')

# %%
# Get R2 measure (indicator of accuracy 1 is perfect, 0 is horrible)
lm.score(X_test, Y_test)
# Out:
# 0.36505652667534694

# %% [markdown]
# Toooooooo bad!!

# %% [markdown]
# Guess there maybe some different between test data and train data, so the prediction is not good.

# %% [markdown]
# Let us calcualte $R^2$ and RMSE (Root Mean Square Error) for the train and test sets to further assess the model.
#
# $R^2$: It is the percentage of the response variable variation that is explained by a linear model
#
# RMSE: It is the square root of the mean of squared errors. Squared errors are the difference of actual and predicted values sqaured.

# %%
# R2 for train and test data
R2_reg_train = lm.score(X_train,Y_train)
R2_reg_test = lm.score(X_test,Y_test)
print('R squared for train data is: %.3f' %(R2_reg_train))
print('R squared for test data is: %.3f' %(R2_reg_test))
# Out:
# R squared for train data is: 0.490
# R squared for test data is: 0.365

# %% [markdown]
# - The train set explains more varaince (49%) than the test set (36.5%). This is quite common because the model is trained on training data, training set's $R^2$ is always greater than the test set's $R^2$.
# - Since the train score is more than test score, let us see if it is a case of Overfitting by plotting a Residual Plot

# %%
from math import sqrt
RMSE_reg_train = sqrt(np.mean((Y_train - lm.predict(X_train))**2))
RMSE_reg_test = sqrt(np.mean((Y_test - lm.predict(X_test))**2))
print('Root mean squared error for train data is: %.3f' %(RMSE_reg_train))
print('Root mean sqaured error for test data is: %.3f' %(RMSE_reg_test))
# Out:
# Root mean squared error for train data is: 2.889
# Root mean sqaured error for test data is: 3.088

# %%
sns.residplot(x=lm.predict(X_train), y=Y_train, lowess=True)
plt.title('Residual Plot using train data')
# Out:
# Text(0.5, 1.0, 'Residual Plot using train data')

# %% [markdown]
# Residual plot for the training data shows that the data points lie between -5 to 5.

# %%
sns.residplot(x=lm.predict(X_test), y=Y_test, lowess=True)
plt.title('Residual Plot using test data')
# Out:
# Text(0.5, 1.0, 'Residual Plot using test data')

# %% [markdown]
# Test data is also showing the same range from the reference line.

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.hlines(y = 0, xmin=0, xmax = 50)
plt.title('Residual Plot using training (blue) and test (green) data')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# The blue dots represent train data and green dots represent test data. From the residual plot above it is evident that the model is a good fit for test data as well. The data lies between +/- 5 from the reference line.

# %% [markdown]
# **Analysis:**
# - The regression line appears to be a **good fit for the data**.
# - The train and test scores not being too different form each other, indiactes that there is **no Overfitting**.
# - The distribution of test and train data looks similar in the residual plot, which says that there is **no big difference in residuals**. And the data is spread around -5 and 5.

# %% [markdown]
# So maybe we should try another model

# %% [markdown]
# ### Now let's try RandomForest

# %%
type(Y_test)
# Out:
# pandas.core.series.Series

# %%
from sklearn.ensemble import RandomForestRegressor
# Create a model 
rf_model = RandomForestRegressor()

# Train the model
rf_model.fit(X_train, Y_train)
# Out:
# G:\Software\anaconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
# Get R2 measure (indicator of accuracy 1 is perfect, 0 is horrible)
rf_model.score(X_test, Y_test)
# Out:
# 0.4715086568835537

# %% [markdown]
# That's much better, but also not good enough. Let's plot the data to see what happend.

# %%
y_pred = rf_model.predict(X_test)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.plot(y_pred)

# %%
y_test = Y_test.as_matrix()
type(y_test)
# Out:
# G:\Software\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# numpy.ndarray

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
type(Y_test)
# Out:
# pandas.core.series.Series

# %%
pd.concat([pd.Series(y_pred), Y_test.reset_index(drop=True)], axis=1)
# Out:
#           0  Unemployment_Ratio
# 0     6.807                8.76
# 1    23.650               22.14
# 2     6.195                5.85
# 3     9.234               14.24
# 4     7.955                9.39
# ..      ...                 ...
# 133  12.319                8.75
# 134   7.802                9.46
# 135   7.244               12.75
# 136   7.751                7.85
# 137   8.931                7.57
#
# [138 rows x 2 columns]

# %%
importances = rf_model.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf_model.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

print("Features:")
print("0.Population_Density")
print("1.Student_Number")
print("2.Teacher_Ratio")
print("3.Child_Poverty_Ratio")
print("4.Attend_College_Ratio")
print("5.Poverty_School")
print(" ")

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Features:
# 0.Population_Density
# 1.Student_Number
# 2.Teacher_Ratio
# 3.Child_Poverty_Ratio
# 4.Attend_College_Ratio
# 5.Poverty_School
#
# Feature ranking:
# 1. feature 5 (0.664162)
# 2. feature 4 (0.126302)
# 3. feature 0 (0.069653)
# 4. feature 2 (0.058490)
# 5. feature 1 (0.049443)
# 6. feature 3 (0.031950)
